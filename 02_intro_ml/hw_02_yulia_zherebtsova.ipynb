# %% [markdown]
# # DataGym
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не знаем)

# %%
df_train = pd.read_csv('otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head().T
# Out:
#                                                       0  \
# AGREEMENT_RK                                   59910150
# TARGET                                                0
# AGE                                                  49
# SOCSTATUS_WORK_FL                                     1
# SOCSTATUS_PENS_FL                                     0
# GENDER                                                1
# CHILD_TOTAL                                           2
# DEPENDANTS                                            1
# EDUCATION                           Среднее специальное
# MARITAL_STATUS                           Состою в браке
# GEN_INDUSTRY                                   Торговля
# GEN_TITLE                                       Рабочий
# ORG_TP_STATE                           Частная компания
# ORG_TP_FCAPITAL                             Без участия
# JOB_DIR                     Вспомогательный техперсонал
# FAMILY_INCOME                    от 10000 до 20000 руб.
# PERSONAL_INCOME                                    5000
# REG_ADDRESS_PROVINCE               Оренбургская область
# FACT_ADDRESS_PROVINCE              Оренбургская область
# POSTAL_ADDRESS_PROVINCE            Оренбургская область
# TP_PROVINCE                        Оренбургская область
# REGION_NM                                    ПОВОЛЖСКИЙ
# REG_FACT_FL                                           1
# FACT_POST_FL                                          1
# REG_POST_FL                                           1
# REG_FACT_POST_FL                                      1
# REG_FACT_POST_TP_FL                                   1
# FL_PRESENCE_FL                                        0
# OWN_AUTO                                              0
# AUTO_RUS_FL                                           0
# HS_PRESENCE_FL                                        0
# COT_PRESENCE_FL                                       0
# GAR_PRESENCE_FL                                       0
# LAND_PRESENCE_FL                                      0
# CREDIT                                             8000
# TERM                                                  6
# FST_PAYMENT                                        8650
# DL_DOCUMENT_FL                                        0
# GPF_DOCUMENT_FL                                       1
# FACT_LIVING_TERM                                    220
# WORK_TIME                                            18
# FACT_PHONE_FL                                         0
# REG_PHONE_FL                                          0
# GEN_PHONE_FL                                          1
# LOAN_NUM_TOTAL                                        1
# LOAN_NUM_CLOSED                                       1
# LOAN_NUM_PAYM                                         6
# LOAN_DLQ_NUM                                          2
# LOAN_MAX_DLQ                                          1
# LOAN_AVG_DLQ_AMT                                   1580
# LOAN_MAX_DLQ_AMT                                   1580
# PREVIOUS_CARD_NUM_UTILIZED                          NaN
#
#                                                          1  \
# AGREEMENT_RK                                      59910230
# TARGET                                                   0
# AGE                                                     32
# SOCSTATUS_WORK_FL                                        1
# SOCSTATUS_PENS_FL                                        0
# GENDER                                                   1
# CHILD_TOTAL                                              3
# DEPENDANTS                                               3
# EDUCATION                                          Среднее
# MARITAL_STATUS                              Состою в браке
# GEN_INDUSTRY                                      Торговля
# GEN_TITLE                                          Рабочий
# ORG_TP_STATE                Индивидуальный предприниматель
# ORG_TP_FCAPITAL                                Без участия
# JOB_DIR                      Участие в основ. деятельности
# FAMILY_INCOME                       от 10000 до 20000 руб.
# PERSONAL_INCOME                                      12000
# REG_ADDRESS_PROVINCE                    Кабардино-Балкария
# FACT_ADDRESS_PROVINCE                   Кабардино-Балкария
# POSTAL_ADDRESS_PROVINCE                 Кабардино-Балкария
# TP_PROVINCE                            Ставропольский край
# REGION_NM                                            ЮЖНЫЙ
# REG_FACT_FL                                              1
# FACT_POST_FL                                             1
# REG_POST_FL                                              1
# REG_FACT_POST_FL                                         1
# REG_FACT_POST_TP_FL                                      0
# FL_PRESENCE_FL                                           0
# OWN_AUTO                                                 0
# AUTO_RUS_FL                                              0
# HS_PRESENCE_FL                                           0
# COT_PRESENCE_FL                                          0
# GAR_PRESENCE_FL                                          0
# LAND_PRESENCE_FL                                         0
# CREDIT                                               21650
# TERM                                                     6
# FST_PAYMENT                                           4000
# DL_DOCUMENT_FL                                           0
# GPF_DOCUMENT_FL                                          1
# FACT_LIVING_TERM                                       137
# WORK_TIME                                               97
# FACT_PHONE_FL                                            1
# REG_PHONE_FL                                             0
# GEN_PHONE_FL                                             1
# LOAN_NUM_TOTAL                                           1
# LOAN_NUM_CLOSED                                          1
# LOAN_NUM_PAYM                                            6
# LOAN_DLQ_NUM                                             1
# LOAN_MAX_DLQ                                             1
# LOAN_AVG_DLQ_AMT                                      4020
# LOAN_MAX_DLQ_AMT                                      4020
# PREVIOUS_CARD_NUM_UTILIZED                             NaN
#
#                                                         2  \
# AGREEMENT_RK                                     59910525
# TARGET                                                  0
# AGE                                                    52
# SOCSTATUS_WORK_FL                                       1
# SOCSTATUS_PENS_FL                                       0
# GENDER                                                  1
# CHILD_TOTAL                                             4
# DEPENDANTS                                              0
# EDUCATION                                Неполное среднее
# MARITAL_STATUS                             Состою в браке
# GEN_INDUSTRY                    Информационные технологии
# GEN_TITLE                                      Специалист
# ORG_TP_STATE                 Государственная комп./учреж.
# ORG_TP_FCAPITAL                               Без участия
# JOB_DIR                     Участие в основ. деятельности
# FAMILY_INCOME                      от 10000 до 20000 руб.
# PERSONAL_INCOME                                      9000
# REG_ADDRESS_PROVINCE                    Иркутская область
# FACT_ADDRESS_PROVINCE                   Иркутская область
# POSTAL_ADDRESS_PROVINCE                 Иркутская область
# TP_PROVINCE                             Иркутская область
# REGION_NM                              ВОСТОЧНО-СИБИРСКИЙ
# REG_FACT_FL                                             1
# FACT_POST_FL                                            1
# REG_POST_FL                                             1
# REG_FACT_POST_FL                                        1
# REG_FACT_POST_TP_FL                                     1
# FL_PRESENCE_FL                                          0
# OWN_AUTO                                                0
# AUTO_RUS_FL                                             0
# HS_PRESENCE_FL                                          1
# COT_PRESENCE_FL                                         0
# GAR_PRESENCE_FL                                         0
# LAND_PRESENCE_FL                                        0
# CREDIT                                              33126
# TERM                                                   12
# FST_PAYMENT                                          4000
# DL_DOCUMENT_FL                                          0
# GPF_DOCUMENT_FL                                         1
# FACT_LIVING_TERM                                      251
# WORK_TIME                                              84
# FACT_PHONE_FL                                           0
# REG_PHONE_FL                                            0
# GEN_PHONE_FL                                            1
# LOAN_NUM_TOTAL                                          2
# LOAN_NUM_CLOSED                                         1
# LOAN_NUM_PAYM                                          11
# LOAN_DLQ_NUM                                            0
# LOAN_MAX_DLQ                                            0
# LOAN_AVG_DLQ_AMT                                        0
# LOAN_MAX_DLQ_AMT                                        0
# PREVIOUS_CARD_NUM_UTILIZED                            NaN
#
#                                                         3  \
# AGREEMENT_RK                                     59910803
# TARGET                                                  0
# AGE                                                    39
# SOCSTATUS_WORK_FL                                       1
# SOCSTATUS_PENS_FL                                       0
# GENDER                                                  1
# CHILD_TOTAL                                             1
# DEPENDANTS                                              1
# EDUCATION                                          Высшее
# MARITAL_STATUS                             Состою в браке
# GEN_INDUSTRY                                  Образование
# GEN_TITLE                     Руководитель среднего звена
# ORG_TP_STATE                 Государственная комп./учреж.
# ORG_TP_FCAPITAL                               Без участия
# JOB_DIR                     Участие в основ. деятельности
# FAMILY_INCOME                      от 20000 до 50000 руб.
# PERSONAL_INCOME                                     25000
# REG_ADDRESS_PROVINCE                   Ростовская область
# FACT_ADDRESS_PROVINCE                  Ростовская область
# POSTAL_ADDRESS_PROVINCE                Ростовская область
# TP_PROVINCE                            Ростовская область
# REGION_NM                                           ЮЖНЫЙ
# REG_FACT_FL                                             0
# FACT_POST_FL                                            1
# REG_POST_FL                                             0
# REG_FACT_POST_FL                                        0
# REG_FACT_POST_TP_FL                                     1
# FL_PRESENCE_FL                                          1
# OWN_AUTO                                                0
# AUTO_RUS_FL                                             0
# HS_PRESENCE_FL                                          0
# COT_PRESENCE_FL                                         0
# GAR_PRESENCE_FL                                         0
# LAND_PRESENCE_FL                                        0
# CREDIT                                            8491,82
# TERM                                                    6
# FST_PAYMENT                                          5000
# DL_DOCUMENT_FL                                          0
# GPF_DOCUMENT_FL                                         0
# FACT_LIVING_TERM                                       36
# WORK_TIME                                             168
# FACT_PHONE_FL                                           1
# REG_PHONE_FL                                            1
# GEN_PHONE_FL                                            1
# LOAN_NUM_TOTAL                                          1
# LOAN_NUM_CLOSED                                         1
# LOAN_NUM_PAYM                                           6
# LOAN_DLQ_NUM                                            3
# LOAN_MAX_DLQ                                            1
# LOAN_AVG_DLQ_AMT                         1589,92333333333
# LOAN_MAX_DLQ_AMT                                     1590
# PREVIOUS_CARD_NUM_UTILIZED                            NaN
#
#                                                         4
# AGREEMENT_RK                                     59911781
# TARGET                                                  0
# AGE                                                    30
# SOCSTATUS_WORK_FL                                       1
# SOCSTATUS_PENS_FL                                       0
# GENDER                                                  0
# CHILD_TOTAL                                             0
# DEPENDANTS                                              0
# EDUCATION                                         Среднее
# MARITAL_STATUS                             Состою в браке
# GEN_INDUSTRY                       Государственная служба
# GEN_TITLE                                      Специалист
# ORG_TP_STATE                 Государственная комп./учреж.
# ORG_TP_FCAPITAL                               Без участия
# JOB_DIR                     Участие в основ. деятельности
# FAMILY_INCOME                      от 10000 до 20000 руб.
# PERSONAL_INCOME                                     12000
# REG_ADDRESS_PROVINCE                   Кабардино-Балкария
# FACT_ADDRESS_PROVINCE                  Кабардино-Балкария
# POSTAL_ADDRESS_PROVINCE                Кабардино-Балкария
# TP_PROVINCE                           Ставропольский край
# REGION_NM                                           ЮЖНЫЙ
# REG_FACT_FL                                             1
# FACT_POST_FL                                            1
# REG_POST_FL                                             1
# REG_FACT_POST_FL                                        1
# REG_FACT_POST_TP_FL                                     0
# FL_PRESENCE_FL                                          0
# OWN_AUTO                                                0
# AUTO_RUS_FL                                             0
# HS_PRESENCE_FL                                          1
# COT_PRESENCE_FL                                         0
# GAR_PRESENCE_FL                                         0
# LAND_PRESENCE_FL                                        0
# CREDIT                                              21990
# TERM                                                   12
# FST_PAYMENT                                          4000
# DL_DOCUMENT_FL                                          0
# GPF_DOCUMENT_FL                                         1
# FACT_LIVING_TERM                                       83
# WORK_TIME                                             101
# FACT_PHONE_FL                                           1
# REG_PHONE_FL                                            0
# GEN_PHONE_FL                                            1
# LOAN_NUM_TOTAL                                          2
# LOAN_NUM_CLOSED                                         1
# LOAN_NUM_PAYM                                          16
# LOAN_DLQ_NUM                                            2
# LOAN_MAX_DLQ                                            1
# LOAN_AVG_DLQ_AMT                                  1152,15
# LOAN_MAX_DLQ_AMT                                     2230
# PREVIOUS_CARD_NUM_UTILIZED                            NaN

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать со sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train['sample'] = 'train'
df_test['sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns:                  # перебираем все столбцы
    if str(df_train[i].dtype) == 'object':  # если тип столбца - object
        print('='*10)
        print(i)                            # выводим название столбца
        print(set(df_train[i]))             # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n')                         # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Среднее специальное', 'Два и более высших образования', 'Высшее', 'Ученая степень', 'Среднее', 'Неоконченное высшее', 'Неполное среднее'}
#
#
# ==========
# MARITAL_STATUS
# {'Разведен(а)', 'Вдовец/Вдова', 'Состою в браке', 'Гражданский брак', 'Не состоял в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {'Образование', nan, 'Банк/Финансы', 'Недвижимость', 'Государственная служба', 'Логистика', 'Энергетика', 'Коммунальное хоз-во/Дорожные службы', 'Здравоохранение', 'Информационные технологии', 'Туризм', 'Юридические услуги/нотариальные услуги', 'Страхование', 'Информационные услуги', 'Сельское хозяйство', 'Сборочные производства', 'Наука', 'Металлургия/Промышленность/Машиностроение', 'Торговля', 'СМИ/Реклама/PR-агенства', 'ЧОП/Детективная д-ть', 'Химия/Парфюмерия/Фармацевтика', 'Другие сферы', 'Ресторанный бизнес/Общественное питание', 'Салоны красоты и здоровья', 'Управляющая компания', 'Нефтегазовая промышленность', 'Транспорт', 'Строительство', 'Маркетинг', 'Развлечения/Искусство', 'Подбор персонала'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Руководитель среднего звена', 'Высококвалифиц. специалист', 'Партнер', 'Военнослужащий по контракту', 'Специалист', 'Руководитель высшего звена', 'Служащий', 'Руководитель низшего звена', 'Рабочий', 'Работник сферы услуг', 'Индивидуальный предприниматель', 'Другое'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Частная компания', 'Индивидуальный предприниматель'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
#
# ==========
# JOB_DIR
# {nan, 'Бухгалтерия, финансы, планир.', 'Служба безопасности', 'Кадровая служба и секретариат', 'Юридическая служба', 'Снабжение и сбыт', 'Адм-хоз. и трансп. службы', 'Вспомогательный техперсонал', 'Реклама и маркетинг', 'Участие в основ. деятельности', 'Пр-техн. обесп. и телеком.'}
#
#
# ==========
# FAMILY_INCOME
# {'от 10000 до 20000 руб.', 'от 20000 до 50000 руб.', 'до 5000 руб.', 'свыше 50000 руб.', 'от 5000 до 10000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'9300', '25000', '23500', '5050', '6180', '6800', '16500', '3800', '14500', '16800', '75000', '9330', '14300', '3900', '160000', '8900', '9100', '7100', '7400', '9628', '2100', '17500', '24500', '19000', '13500', '9200', '10800', '44000', '15560', '4200', '24000', '5900', '8000', '32640', '13160', '10900', '5600', '17800', '5400', '21000', '9700', '17600', '13000', '7700', '20646,16', '12600', '19500', '16000', '56000', '4000', '24800', '35000', '37000', '15500', '39000', '33000', '15000', '11900', '38000', '4950', '8250', '5460', '8726', '5350', '5800', '250000', '20000', '6200', '100000', '42000', '3400', '29000', '7830', '12100', '5088', '5300', '11700', '6900', '34000', '6100', '54000', '21500', '9400', '7220', '15400', '42500', '4515', '13150', '60000', '18500', '43000', '28300', '16900', '6359', '11500', '19600', '4590', '8350', '10600', '12500', '12650', '15600', '16100', '9000', '12000', '8066', '23000', '36000', '3700', '12900', '13800', '7250', '17900', '22000', '50000', '11400', '5230', '67700', '170000', '110000', '19800', '41900', '26500', '3100', '4900', '5425', '11300', '7050', '4800', '6000', '6299,19', '7850', '10000', '6500', '5446', '20500', '8600', '150000', '15300', '5000', '13900', '1950', '9900', '8800', '53000', '18600', '2000', '12300', '8300', '12400', '6600', '14358', '10100', '17404', '27000', '4400', '7900', '2300', '9240', '15380', '7550', '7251', '6608', '13200', '6300', '4330', '5582', '16050', '2800', '10300', '45000', '40000', '10400', '30000', '17200', '80000', '13450', '8400', '12800', '13700', '7101', '29500', '9800', '3300', '3500', '41000', '13400', '5680', '3600', '28000', '7640', '13300', '5360', '68000', '5100', '49000', '10700', '14800', '13600', '17700', '7000', '26000', '46000', '15200', '22955', '4500', '4340', '27300', '7650', '25800', '48000', '23800', '12700', '22500', '14000', '3000', '5700', '8200', '70000', '11600', '31000', '5339', '77000', '10500', '92000', '52000', '17000', '9600', '8700', '21800', '6400', '9340', '220000', '18700', '11640', '11200', '8500', '24', '29800', '18200', '14700', '4600', '7500', '18000', '6670', '10200', '11000', '4360', '5790', '7300', '7800', '47000', '19700', '5500', '19300', '16200', '3200', '16700', '4300', '7200', '55000', '7600', '4700', '5200', '9500', '32000', '6700', '23100', '8100', '4100', '65000', '11800', '67000', '51000'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Ивановская область', 'Ставропольский край', 'Ленинградская область', 'Ульяновская область', 'Тверская область', 'Костромская область', 'Мордовская республика', 'Курская область', 'Красноярский край', 'Калининградская область', 'Удмуртия', 'Карелия', 'Дагестан', 'Карачаево-Черкесия', 'Самарская область', 'Калмыкия', 'Кемеровская область', 'Якутия', 'Псковская область', 'Пермская область', 'Томская область', 'Башкирия', 'Владимирская область', 'Сахалинская область', 'Волгоградская область', 'Орловская область', 'Амурская область', 'Саратовская область', 'Ямало-Ненецкий АО', 'Алтайский край', 'Ханты-Мансийский АО', 'Хабаровский край', 'Кабардино-Балкария', 'Адыгея', 'Читинская область', 'Коми', 'Оренбургская область', 'Воронежская область', 'Вологодская область', 'Челябинская область', 'Калужская область', 'Липецкая область', 'Кировская область', 'Приморский край', 'Смоленская область', 'Агинский Бурятский АО', 'Московская область', 'Новосибирская область', 'Чувашия', 'Ярославская область', 'Ростовская область', 'Марийская республика', 'Бурятия', 'Астраханская область', 'Татарстан', 'Рязанская область', 'Архангельская область', 'Еврейская АО', 'Москва', 'Северная Осетия', 'Иркутская область', 'Свердловская область', 'Курганская область', 'Тюменская область', 'Хакасия', 'Тульская область', 'Брянская область', 'Пензенская область', 'Тамбовская область', 'Камчатская область', 'Белгородская область', 'Краснодарский край', 'Санкт-Петербург', 'Омская область', 'Усть-Ордынский Бурятский АО', 'Магаданская область', 'Мурманская область', 'Новгородская область', 'Горный Алтай', 'Нижегородская область', 'Эвенкийский АО'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ивановская область', 'Ставропольский край', 'Ленинградская область', 'Ульяновская область', 'Тверская область', 'Костромская область', 'Мордовская республика', 'Курская область', 'Красноярский край', 'Калининградская область', 'Удмуртия', 'Карелия', 'Дагестан', 'Карачаево-Черкесия', 'Самарская область', 'Калмыкия', 'Кемеровская область', 'Якутия', 'Псковская область', 'Пермская область', 'Томская область', 'Башкирия', 'Владимирская область', 'Сахалинская область', 'Волгоградская область', 'Орловская область', 'Амурская область', 'Саратовская область', 'Ямало-Ненецкий АО', 'Алтайский край', 'Ханты-Мансийский АО', 'Хабаровский край', 'Кабардино-Балкария', 'Адыгея', 'Читинская область', 'Коми', 'Оренбургская область', 'Воронежская область', 'Вологодская область', 'Челябинская область', 'Калужская область', 'Липецкая область', 'Кировская область', 'Приморский край', 'Смоленская область', 'Агинский Бурятский АО', 'Московская область', 'Новосибирская область', 'Чувашия', 'Ярославская область', 'Ростовская область', 'Марийская республика', 'Бурятия', 'Астраханская область', 'Татарстан', 'Рязанская область', 'Архангельская область', 'Еврейская АО', 'Москва', 'Северная Осетия', 'Иркутская область', 'Свердловская область', 'Курганская область', 'Тюменская область', 'Хакасия', 'Тульская область', 'Брянская область', 'Пензенская область', 'Тамбовская область', 'Камчатская область', 'Белгородская область', 'Краснодарский край', 'Санкт-Петербург', 'Омская область', 'Усть-Ордынский Бурятский АО', 'Магаданская область', 'Мурманская область', 'Новгородская область', 'Горный Алтай', 'Нижегородская область', 'Эвенкийский АО'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ивановская область', 'Ставропольский край', 'Ленинградская область', 'Ульяновская область', 'Тверская область', 'Костромская область', 'Мордовская республика', 'Курская область', 'Красноярский край', 'Калининградская область', 'Удмуртия', 'Карелия', 'Карачаево-Черкесия', 'Самарская область', 'Калмыкия', 'Кемеровская область', 'Якутия', 'Псковская область', 'Пермская область', 'Томская область', 'Башкирия', 'Владимирская область', 'Сахалинская область', 'Волгоградская область', 'Орловская область', 'Амурская область', 'Саратовская область', 'Ямало-Ненецкий АО', 'Алтайский край', 'Ханты-Мансийский АО', 'Хабаровский край', 'Кабардино-Балкария', 'Адыгея', 'Читинская область', 'Коми', 'Оренбургская область', 'Воронежская область', 'Вологодская область', 'Челябинская область', 'Калужская область', 'Липецкая область', 'Кировская область', 'Приморский край', 'Смоленская область', 'Агинский Бурятский АО', 'Московская область', 'Новосибирская область', 'Чувашия', 'Ярославская область', 'Ростовская область', 'Марийская республика', 'Бурятия', 'Астраханская область', 'Татарстан', 'Рязанская область', 'Архангельская область', 'Еврейская АО', 'Москва', 'Северная Осетия', 'Иркутская область', 'Свердловская область', 'Курганская область', 'Тюменская область', 'Хакасия', 'Тульская область', 'Брянская область', 'Пензенская область', 'Тамбовская область', 'Камчатская область', 'Белгородская область', 'Краснодарский край', 'Санкт-Петербург', 'Омская область', 'Усть-Ордынский Бурятский АО', 'Магаданская область', 'Мурманская область', 'Новгородская область', 'Горный Алтай', 'Нижегородская область', 'Эвенкийский АО'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Ивановская область', 'Курганская область', 'Ставропольский край', 'Тюменская область', 'Башкирия', 'Пермская область', 'Тульская область', 'Новосибирская область', 'Владимирская область', 'Брянская область', 'Пензенская область', 'Сахалинская область', 'Ульяновская область', 'Тверская область', 'Чувашия', 'Ярославская область', 'Тамбовская область', 'Волгоградская область', 'Орловская область', 'Камчатская область', 'Приморский край', 'Ростовская область', 'Белгородская область', 'Амурская область', 'Саратовская область', 'Мордовская республика', 'Костромская область', 'Курская область', 'Красноярский край', 'Краснодарский край', 'Санкт-Петербург', 'Калининградская область', 'Удмуртия', 'Смоленская область', 'Карелия', 'Алтайский край', 'Ханты-Мансийский АО', 'Омская область', 'Марийская республика', 'Хабаровский край', 'Мурманская область', 'Магаданская область', 'Кабардино-Балкария', 'Бурятия', 'Самарская область', 'Астраханская область', 'Адыгея', 'Читинская область', 'Горный Алтай', 'Новгородская область', 'Татарстан', 'Коми', 'Оренбургская область', 'Воронежская область', 'Вологодская область', 'Челябинская область', 'Калужская область', 'Рязанская область', 'Архангельская область', 'Еврейская АО', 'Липецкая область', 'Кемеровская область', 'Якутия', 'Псковская область', 'Нижегородская область', 'Москва', 'Кировская область', 'Иркутская область', 'Свердловская область', 'Томская область'}
#
#
# ==========
# REGION_NM
# {nan, 'ПОВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'УРАЛЬСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ЮЖНЫЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'СЕВЕРО-ЗАПАДНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ПРИВОЛЖСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ'}
#
#
# ==========
# CREDIT
# {'9456', '15980', '14175', '19854', '21907', '4799', '5380', '31499', '14035', '15165', '20095', '5359', '3717,9', '9588', '10900', '13768', '28172', '4743', '93000', '6103', '9880', '20710', '19520', '7890', '3798,9', '7182', '2330', '8730', '5419', '13689,86', '13456,82', '5825', '11900', '10423', '41620', '5510', '10520', '32955', '30520', '13155', '19580', '14522', '16653', '7909', '8370', '12560,01', '3270', '25587', '17184', '20268', '33183,4', '7752', '24752', '13080', '6237,03', '9576', '17605', '13830', '27780', '11748,2', '10880', '10655', '14758', '6883', '16691', '7711', '21498', '7713,42', '11892', '16950', '5579', '67500', '29990', '4777', '3744', '19920', '23784', '18398', '13010,94', '7790', '28557', '51300', '8610', '10618', '11460', '7595', '10440', '12509,9', '3717', '33470', '5261', '16635', '10991', '5152', '13326,5', '6692', '16579', '17099,1', '8641', '8957', '17981,9', '62700', '20660', '27620', '10295', '9800', '2489', '4148', '32846', '4140,2', '4720', '16098', '9917', '3329', '3560', '11689', '78150',
651,16', '1098,8', '5780', '3510', '3070', '2120', '976,68', '1580', '599,19', '1761,03', '2261,19', '2110', '791,56', '574,21', '2425', '3020', '4370', '2700', '5870', '0,04', '2497', '1760', '673,02', '1439,9', '2379,46', '4210', '2409,01', '4884,95', '770', '3940', '610', '3050', '2102,75', '4830', '678,2', '790', '989,39', '18310', '3500', '2059,46', '687,11', '3283,1', '1068,47', '3964,85', '1250', '588,13', '790,77', '2890', '51,8', '4250', '1539,13', '682', '620,75', '3560', '2770', '823,54', '1052,63', '470', '797,16', '800', '2250', '613,21', '910', '600', '1670,18', '880,2', '3540', '1370', '1959,99', '1980', '1990', '3410', '3018,62', '6260', '446,31', '1563,45', '3000', '1144,03', '4620', '2957,71', '869,26', '668,53', '497,62', '818,74', '2492,54', '1940', '3716,35', '3310', '4880', '1663,27', '28012,2', '1249,61', '1819,09', '4770', '1365', '2858,6', '816,83', '2050', '981,71', '2398,8', '749,82', '1015', '806,19', '1330', '1610', '2343,41', '1095,89', '5170', '762,93', '896,31', '1550', '1296,74', '2573,8', '2140', '1530', '2670', '2660', '3702,8', '2810', '473,16', '1750', '1302,38', '726,57', '1770', '2540', '620,18', '7340', '960', '5048,19', '2990', '5076,65', '9280', '4140', '887,79', '1440', '3237,94', '1710', '1730', '755,76', '1729,66', '2064,08', '3506,07', '2005,15', '1731,06', '1549,18', '2100', '1090,8', '1196,43', '552,57', '937,6', '510', '730', '1296,4', '3840', '4729,07', '660,86', '407,8', '2779,4', '430', '1150', '2462,1', '2549,52', '1615', '830', '1679,2', '1138,2', '918,83', '827,57', '4000', '2520', '1740,19', '937,79', '910,63', '339,83', '1670', '3150', '1093,75', '3768,7', '3762,5', '849,19', '540', '766,26', '991,19', '3360', '2589,2', '1591,94', '2701,26', '1190', '472,11', '4710', '2820', '1110,39', '4690', '4070', '553', '2178', '1299,55', '100', '1360', '950', '2200', '580', '2470', '919,88', '4650', '3960', '1953,6', '1395,7', '572,22', '2088,86', '2618,78', '310', '760', '2699,88', '3470', '2372,77', '1127,76', '3460', '5394,29', '568,7', '2260', '6689,82', '1519,64', '1351,06', '4001,34', '2112,17', '710', '1966,99', '1260', '567,51', '2002,45', '880', '2060', '2349,51', '4508,2', '2239,37', '5040', '438,19', '900', '1749,69', '1387,3', '63,31', '3330', '1335,47', '1380', '1208,09', '740', '2980', '1800', '3120', '1706,3', '1450', '943,56', '2084,32', '2300', '1317,06', '3040', '5320', '2910', '2858,62', '791,98', '5760', '5550', '3820', '883,33', '1477,37', '2270', '1120,93', '1283,93', '3357,52', '2281,1', '1590', '4660', '1630', '2870', '2320', '2979,35', '3539,82', '917,57', '2650', '1033', '2210', '478,13', '1095,61', '1910', '49,35', '87,39', '684,89', '3089,5', '1716,52', '673,89', '1420', '1200,99', '1175,57', '115,65', '849,07', '783', '1119,27', '4240', '2750', '489,13', '2044,32', '1056,64', '650', '1880,59', '2629,87', '812,11', '4680', ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float');
# так это исправляется, но результат не записывается никуда)

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Заполните их нулями

# %%
df.info() 
# пропуски есть в восьми столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %%
df.fillna(0).info() # можно заполнить нулями следующим образом, сохраним результат позже
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  30133 non-null object
# GEN_TITLE                     30133 non-null object
# ORG_TP_STATE                  30133 non-null object
# ORG_TP_FCAPITAL               30133 non-null object
# JOB_DIR                       30133 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   30133 non-null object
# REGION_NM                     30133 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     30133 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    30133 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# #### Задание 2. В данных есть признаки, которые можно назвать категориальным, например семейный статус
#  {'Состою в браке', 'Разведен(а)', 'Не состоял в браке', 'Вдовец/Вдова', 'Гражданский брак'}
#  и таких много
# #### Закодируйте их числами (например идентификаторами 1, 2, 3, ... )
# #### Можно иначе, если есть идеи как.

# %% [markdown]
#  Ответ:
#
#  Всего категориальных столбцов в датасете 13, а также sample:
#
# - EDUCATION
# - MARITAL_STATUS
# - GEN_INDUSTRY
# - GEN_TITLE
# - ORG_TP_STATE
# - ORG_TP_FCAPITAL
# - JOB_DIR
# - FAMILY_INCOME
# - REG_ADDRESS_PROVINCE
# - FACT_ADDRESS_PROVINCE
# - POSTAL_ADDRESS_PROVINCE
# - TP_PROVINCE
# - REGION_NM
# - sample
#
# Закодируем их от 1 до m, где m - количество возможных значений столбца (в том числе sample для единообразия). Реализация приведена в функции preprocess_data в рамках Задания №3 ниже.

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками (см задание 1)
# * Кодировала категориальные признаки (см задание 2) Если закодировать признаки вам не удалось - удалите все что не числа
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preprocess_data(df_input):
    df_output = df_input.copy()
    
    # удаляеим идентификатор AGREEMENT_RK
    df_output = df_output.drop('AGREEMENT_RK', axis=1)
    
    # избавляемся от '.' и ',', преобразуем к float из ошибочно определенного типа object
    df_output['PERSONAL_INCOME'] = df_output['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['CREDIT'] = df_output['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['FST_PAYMENT'] = df_output['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_MAX_DLQ_AMT'] = df_output['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_AVG_DLQ_AMT'] = df_output['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')

    
    # кодируем категориальные признаки числами от 1 до кол-ва возможных уникальных значений признака, с шагом 1,
    # при этом пропуски будут кодироваться нулями:
    for column in df_output.columns:
        if str(df_output[column].dtype) == 'object': # если столбец типа object, 
            # получаем массив возможные уникальные значения признака,
            # приводим их к одному типу и сортируем так, чтобы пропуск стоял первым, если он имеется
            values_to_encode = sorted(list(map(lambda x: str(x), df_output[column].unique())))

            if str(np.nan) in values_to_encode:
                start = 0  # если в столбце был пропуск, не нумеруем его, закодируем нулем позже
            else:
                start = 1 # если пропусков не было, просто нумеруем все значения с единицы
            
            # создаем словарь, где ключом является значение признака, 
            # а значением - его кодировка (= порядковый номер в списке возможных значений values_to_encode)
            values_dict = dict(zip(
                                    values_to_encode, 
                                    range(start, len(values_to_encode)+1)
                                   )
                                )
            
            # перекодируем столбец в соответствие с созданным словарем, NaN не кодируется
            df_output[column] = df_output[column].map(values_dict)

            # сохраняем кодировку в файл label_encoding.csv, чтобы не забыть, каким значением что закодировано
            with open('label_encoding.csv', 'a') as file:
                file.write('======'+ column + '=====\n')
                for key in values_dict.keys():
                    file.write("%s,%s\n"%(key, values_dict[key]))
                    
    # заменяем пропуски нулями во всем датасете
    df_output.fillna(0, inplace=True)
            
    return df_output

# %%
df_preproc = df.pipe(preprocess_data)

# %%
df_preproc.info()
# все пропуски заполнены, все столбцы численные
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 52 columns):
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null int64
# MARITAL_STATUS                30133 non-null int64
# GEN_INDUSTRY                  30133 non-null float64
# GEN_TITLE                     30133 non-null float64
# ORG_TP_STATE                  30133 non-null float64
# ORG_TP_FCAPITAL               30133 non-null float64
# JOB_DIR                       30133 non-null float64
# FAMILY_INCOME                 30133 non-null int64
# PERSONAL_INCOME               30133 non-null float64
# REG_ADDRESS_PROVINCE          30133 non-null int64
# FACT_ADDRESS_PROVINCE         30133 non-null int64
# POSTAL_ADDRESS_PROVINCE       30133 non-null int64
# TP_PROVINCE                   30133 non-null float64
# REGION_NM                     30133 non-null float64
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null float64
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null float64
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     30133 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null float64
# LOAN_MAX_DLQ_AMT              30133 non-null float64
# PREVIOUS_CARD_NUM_UTILIZED    30133 non-null float64
# sample                        30133 non-null int64
# dtypes: float64(14), int64(38)
# memory usage: 12.0 MB

# %% [markdown]
# #### Задание 4. Выше мы собрали данные в один датафрейм и записали столбец sample, чтоб было видно где что осталось.
# #### ... напишите код, который разделит df_preproc на 2 части train и test (записав в df_train_preproc и df_test_preproc соответственно)
# #### ... удалив колонку sample

# %%
# в получившейся кодировке test -> 1, train -> 2, делим выборки на основании нового значения признака
df_test_preproc = df_preproc[df_preproc['sample']==1]
df_train_preproc = df_preproc[df_preproc['sample']==2]

# %% [markdown]
# #### Задание 5. Отделите целевую переменную и остальные признаки (речь не про train_test_split)
# Выше у вас получились матрицы df_train_preproc и df_test_preproc
#
# Должно получиться:
# * 2 матрицы: X и X_valid
# * 2 вектора: y и y_valid
#
#
# * где X - все данные df_train_preproc, кроме TARGET
# * где X_valid - все данные df_test_preproc, кроме TARGET
# * где y - TARGET от df_train_preproc
# * где y_valid - TARGET от df_test_preproc

# %%
X = df_train_preproc.drop('TARGET', axis=1)
X_valid = df_test_preproc.drop('TARGET', axis=1)
y = df_train_preproc['TARGET']
y_valid = df_test_preproc['TARGET']

# %% [markdown]
# #### Задание 6. Обучение и оценка качества разных моделей

# %%
# Поделите данные X и y на 2 части (train и test, размером от исходного 70% и 30% соответственно)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.3)

# %%
# Попробовать следующие "черные ящики": интерфейс у всех одинаковый 
# Постепенно мы узнаем, что они делают, а сейчас учимся выбирать? какой работает качественнее
#     fit, 
#     predict
# записав предсказания в pred_1, pred_2, pred_3

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(penalty='l1')
lr.fit(X_train, y_train) # обучаем модель (логистическая регрессия)
pred_1 = lr.predict(X_test) # выдаем ответ

forest = RandomForestClassifier()
forest.fit(X_train, y_train) # обучаем модель (случайный лес)
pred_2 = forest.predict(X_test) # выдаем ответ

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train) # обучаем модель (дерево принятия решений)
pred_3 = tree.predict(X_test) # выдаем ответ
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall, F1
# в pred_1, pred_2, pred_3 у вас должны лежать предсказания разных "ящиков"
# посчитайте метрики для каждого

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
lr_metrics = accuracy_score(y_test, pred_1), \
precision_score(y_test, pred_1), \
recall_score(y_test, pred_1), \
f1_score(y_test, pred_1)

# %%
forest_metrics = accuracy_score(y_test, pred_2), \
precision_score(y_test, pred_2), \
recall_score(y_test, pred_2), \
f1_score(y_test, pred_2)

# %%
tree_metrics = accuracy_score(y_test, pred_3), \
precision_score(y_test, pred_3), \
recall_score(y_test, pred_3), \
f1_score(y_test, pred_3)

# %%
# Визуализровать эти метрики всех моделей на одном графике (чтоб визуально сравнить  качество)
# Возможно вас удивит качество! Но задача подобрана специально ;) Такое качество тоже бывает

# создадим DataFrame, где каждой модели соответствуют значения каждой из метрик
df_metrics = pd.DataFrame(
    [lr_metrics, forest_metrics, tree_metrics], 
    columns = ['accuracy', 'precision', 'recall', 'F1'],
    index = ['logistic regression', 'random forest', 'decision tree'])

# %%
_, ax = plt.subplots(figsize=(15,8))
df_metrics.plot(kind='bar', ax=ax)
plt.xticks(rotation=45)
plt.xlabel('$model$')
plt.ylabel('$metric$ $value$');

# %% [markdown]
# #### Задание 7. Заключительное.
# #### Выше вы можете выборать самую лучшую модель "коробочку" по метрике F1
# #### Теперь вы знаете какой тип коробочки из представленных лучше всего работает на данной задаче
# #### Пора: 1) заново объявить эту коробочку
# #### 2) обучить на всем X,y
# #### 3) протестировать на отложенном X_valid, y_valid

# %%
# Взять лучшую модель и сделать предсказания для X_valid выборки

# По мере F1 лучшей моделью вышел классификатор, основанный на деревьях принятия решений, запустим его на всей выборке
tree = DecisionTreeClassifier()
tree.fit(X, y) 
pred_final = tree.predict(X_valid)

# %%
# Посчитать метрики на полученном предсказании

final_metrics = accuracy_score(y_valid, pred_final), \
precision_score(y_valid, pred_final), \
recall_score(y_valid, pred_final), \
f1_score(y_valid, pred_final)

# %%
fig, ax = plt.subplots(figsize=(10,8))

df_final_metrics = pd.DataFrame(
    [final_metrics], 
    columns = ['accuracy', 'precision', 'recall', 'F1'],
    index = ['decision tree'])

df_final_metrics.plot(kind='bar', ax=ax)
plt.xticks(rotation=0)

plt.xlabel('$model$')
plt.ylabel('$metric value$');
